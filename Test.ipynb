# %% [markdown]
# # Load Data

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content
# !rm -rf face-age
# !git clone -b main https://github.com/KSW11390/face-age.git
# %cd face-age
# Out:
# /content
# Cloning into 'face-age'...
# remote: Enumerating objects: 339, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 339 (delta 3), reused 8 (delta 2), pack-reused 316 (from 1)
# Receiving objects: 100% (339/339), 29.54 MiB | 15.36 MiB/s, done.
# Resolving deltas: 100% (188/188), done.
# /content/face-age

# %%
# !pip install -r requirements.txt -q --progress-bar off

# %%
# ------------------------------------------------------------------
# Please replace ZIP_PATH with the actual path to your UTKFace.zip
# example: "/content/drive/MyDrive/.../UTKFace.zip"
# ------------------------------------------------------------------

ZIP_PATH = "<<YOUR_PATH_HERE"

# !cp "$ZIP_PATH" "/content/"
# !unzip -q "/content/$(basename $ZIP_PATH)" -d "/content/UTKFace"
# Out:
# replace /content/UTKFace/__MACOSX/._UTKFace? [y]es, [n]o, [A]ll, [N]one, [r]ename: N

# %% [markdown]
# # Train

# %%
# !python -m faceage.train \
  --data_root="/content/UTKFace/UTKFace" \
  --epochs=10 \
  --batch_size=32 \
  --lr 1e-4 \
  --model_type resnet \
  --activation gelu \
  --dropout 0.0 \
  --optimizer adamw \
  --weight_decay 1e-4 \
  --width 32 \
  --feat_dim 128 \
  --patience 30 \
  --wandb_project face_age_augmentation \
  --save_dir="/content/drive/MyDrive/MLProject/checkpoints" \
  --label_type soft \
  --loss_fn kld \
  --sigma 2.0 \
	--aug_strength medium \
	--aug_dup 1

# %% [markdown]
# # Inference
# - 200x200 이미지 추가해서 inference 가능
# - 얼굴 주위를 Crop해줘야 예측을 잘 함

# %%
# %matplotlib inline
# %cd /content/face-age

# %run /content/face-age/faceage/inference.py \
    --checkpoint_path "/content/face-age/best_model.pt" \
    --image_path "/content/face-age/faceage/test_images" \
    --width 32 \
    --activation gelu \
    --model_type resnet \
    --feat_dim 128 \
    --img_size 200
